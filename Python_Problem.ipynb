# %%
import json

# %% [markdown]
# json is a one of the python package used to decode and encode json data

# %%
import tweepy

# %% [markdown]
# with help of tweppy we can mine twitter data using API

# %%
import pandas as pd

# %% [markdown]
# pandas is a data visualization and manipulation library used in python

# %%
ACCESS_TOKEN = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
ACCESS_SECRET = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
CONSUMER_KEY = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
CONSUMER_SECRET = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'

# %% [markdown]
# ACCESS_TOKEN,ACCESS_SECRET,CONSUMER_KEY,CONSUMER_SECRET are API keys given by twitter for developers

# %%
username = "midasIIITD"

# %% [markdown]
# Here "username" is which user data we want to get from the twitter

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

# %% [markdown]
# Here tweepy checks authentication of us by our CONSUMER_KEY,CONSUMER_SECRET

# %%
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# %% [markdown]
# After authentication is done tweepy checks ACCESS_TOKEN and ACCESS_SECRET

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %% [markdown]
# Here tweepy.API() assigns to api this says that the user has authenticated,the next parameters controls tweepy to blocking and they waits untill next API calls retuns

# %%
with open('midasIIITD_twitter_data.jsonl', 'w') as outfile: 
    for status in api.user_timeline(screen_name = username,count = 500):
        outfile.write(json.dumps(status._json)+"\n")

# %% [markdown]
# I had opened a json file named as midasIIITD_twitter_data.jsonl with write permission then I had used twitter timeline API to get tweets from the particular username and count defines number of tweets we want.Finally I'd dump the data I got from twitter to the file midasIIID_twitter_data.jsonl.

# %%
df = pd.read_json("midasIIITD_twitter_data.jsonl",lines = True)

# %% [markdown]
#   With help of pandas library I'd read data from midasIITD_twitter_data.jsonl by JSONLines and assigned it to df

# %%
df1 = pd.DataFrame(df,columns = ["text","created_at","favorite_count","retweet_count","media_url_https"])

# %% [markdown]
# With help of pandas library I'd created DataFrame and get specific columns from the DataFrame

# %%
df1
# Out:
#                                                   text          created_at  \
# 0    RT @IIITDelhi: We are delighted to share that ... 2019-04-09 16:45:07
# 1    RT @Harvard: Professor Jelani Nelson founded A... 2019-04-09 05:04:27
# 2    RT @emnlp2019: For anyone interested in submit... 2019-04-09 05:04:11
# 3    RT @multimediaeval: Announcing the 2019 MediaE... 2019-04-08 19:38:09
# 4    Many Congratulations to @midasIIITD student, S... 2019-04-08 07:08:12
# 5    @midasIIITD thanks all students who have appea... 2019-04-08 03:27:42
# 6    @himanchalchandr Meanwhile, complete CV/NLP ta... 2019-04-07 14:17:29
# 7    @sayangdipto123 Submit as per the guideline ag... 2019-04-07 14:17:09
# 8    We request all students whose interview are sc... 2019-04-07 11:43:24
# 9    Other queries: "none of the Tweeter Apis give ... 2019-04-07 06:55:19
# 10   Other queries: "do we have to make two differe... 2019-04-07 06:53:38
# ...
